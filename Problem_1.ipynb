# %%
import pandas as pd

# %%
database = pd.read_csv('https://query.data.world/s/6p2ntncvkzj5mnvbpkaswfilryvnrk')

# %%
database
# Out:
#     x1  x2  x3  x4     y1    y2     y3     y4
# 0   10  10  10   8   8.04  9.14   7.46   6.58
# 1    8   8   8   8   6.95  8.14   6.77   5.76
# 2   13  13  13   8   7.58  8.74  12.74   7.71
# 3    9   9   9   8   8.81  8.77   7.11   8.84
# 4   11  11  11   8   8.33  9.26   7.81   8.47
# 5   14  14  14   8   9.96  8.10   8.84   7.04
# 6    6   6   6   8   7.24  6.13   6.08   5.25
# 7    4   4   4  19   4.26  3.10   5.39  12.50
# 8   12  12  12   8  10.84  9.13   8.15   5.56
# 9    7   7   7   8   4.82  7.26   6.42   7.91
# 10   5   5   5   8   5.68  4.74   5.73   6.89

# %%
df1=pd.DataFrame({'x1':database['x1'],'y1':database['y1']})
df2=pd.DataFrame({'x2':database['x2'],'y2':database['y2']})
df3=pd.DataFrame({'x3':database['x3'],'y3':database['y3']})
df4=pd.DataFrame({'x4':database['x4'],'y4':database['y4']})

# %%
df1
# Out:
#     x1     y1
# 0   10   8.04
# 1    8   6.95
# 2   13   7.58
# 3    9   8.81
# 4   11   8.33
# 5   14   9.96
# 6    6   7.24
# 7    4   4.26
# 8   12  10.84
# 9    7   4.82
# 10   5   5.68

# %%
df2
# Out:
#     x2    y2
# 0   10  9.14
# 1    8  8.14
# 2   13  8.74
# 3    9  8.77
# 4   11  9.26
# 5   14  8.10
# 6    6  6.13
# 7    4  3.10
# 8   12  9.13
# 9    7  7.26
# 10   5  4.74

# %%
df3
# Out:
#     x3     y3
# 0   10   7.46
# 1    8   6.77
# 2   13  12.74
# 3    9   7.11
# 4   11   7.81
# 5   14   8.84
# 6    6   6.08
# 7    4   5.39
# 8   12   8.15
# 9    7   6.42
# 10   5   5.73

# %%
df4
# Out:
#     x4     y4
# 0    8   6.58
# 1    8   5.76
# 2    8   7.71
# 3    8   8.84
# 4    8   8.47
# 5    8   7.04
# 6    8   5.25
# 7   19  12.50
# 8    8   5.56
# 9    8   7.91
# 10   8   6.89

# %%
database.describe()
# Out:
#               x1         x2         x3         x4         y1         y2  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000   7.500909   7.500909
# std     3.316625   3.316625   3.316625   3.316625   2.031568   2.031657
# min     4.000000   4.000000   4.000000   8.000000   4.260000   3.100000
# 25%     6.500000   6.500000   6.500000   8.000000   6.315000   6.695000
# 50%     9.000000   9.000000   9.000000   8.000000   7.580000   8.140000
# 75%    11.500000  11.500000  11.500000   8.000000   8.570000   8.950000
# max    14.000000  14.000000  14.000000  19.000000  10.840000   9.260000
#
#               y3         y4
# count  11.000000  11.000000
# mean    7.500000   7.500909
# std     2.030424   2.030579
# min     5.390000   5.250000
# 25%     6.250000   6.170000
# 50%     7.110000   7.040000
# 75%     7.980000   8.190000
# max    12.740000  12.500000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x = df1['x1'], y = df1['y1'])
plt.title('Data_set_1')
plt.xlabel('x1')
plt.ylabel('y1')
plt.show()

# %%
plt.scatter(x = df2['x2'], y = df2['y2'])
plt.title('Data_set_2')
plt.xlabel('x2')
plt.ylabel('y2')
plt.show()

# %%
plt.scatter(x = df3['x3'], y = df3['y3'])
plt.title('Data_set_3')
plt.xlabel('x3')
plt.ylabel('y3')
plt.show()

# %%
plt.scatter(x = df4['x4'], y = df4['y4'])
plt.title('Data_set_4')
plt.xlabel('x4')
plt.ylabel('y4')
plt.show()

# %% [markdown]
# #### it's visible that all the datasets values have very minor differences, but when it is plotted in a scatter chart it is seen that there is significant variation.
