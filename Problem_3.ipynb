# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/andre/business computing portfolio/user_reviews.csv')

# %%
df
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text        date
# 0     My gf started playing before me. No option to ...  2020-03-20
# 1     While the game itself is great, really relaxin...  2020-03-20
# 2     My wife and I were looking forward to playing ...  2020-03-20
# 3     We need equal values and opportunities for all...  2020-03-20
# 4     BEWARE!  If you have multiple people in your h...  2020-03-20
# ...                                                 ...         ...
# 2994  1 Island for console limitation.I cannot play ...  2020-05-03
# ...

# %%
df['len_text']=''

# %%
df['len_text']=df['text'].str.len()

# %%
df
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text        date  len_text
# 0     My gf started playing before me. No option to ...  2020-03-20       381
# 1     While the game itself is great, really relaxin...  2020-03-20       927
# 2     My wife and I were looking forward to playing ...  2020-03-20      1000
# 3     We need equal values and opportunities for all...  2020-03-20       277
# 4     BEWARE!  If you have multiple people in your h...  2020-03-20       979
# ...                                                 ...         ...       ...
# ...

# %%
df1=df.copy()

# %%
df1['super_category']=''

# %%
df1
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text        date  len_text  \
# 0     My gf started playing before me. No option to ...  2020-03-20       381
# 1     While the game itself is great, really relaxin...  2020-03-20       927
# 2     My wife and I were looking forward to playing ...  2020-03-20      1000
# 3     We need equal values and opportunities for all...  2020-03-20       277
# 4     BEWARE!  If you have multiple people in your h...  2020-03-20       979
# ...                                                 ...         ...       ...
# ...

# %%
x=0

# %%
#using for loop

for x in df1.index:
    if df1.loc[x,'len_text']>1000 and df1.loc[x,'grade']>=9:
        df1.loc[x,'super_category']='Expert reviewer'
    elif df1.loc[x,'len_text']>1000 and df1.loc[x,'grade']<=1:
        df1.loc[x,'super_category']='Opposed reviewer'
    elif df1.loc[x,'len_text']>1000:
        df1.loc[x,'super_category']='Super reviewer'
    else:
         df1.loc[x,'super_category']='Neutral reviewer'
df1.head(50)
# Out:
#     grade        user_name                                               text  \
# 0       4         mds27272  My gf started playing before me. No option to ...
# 1       5         lolo2178  While the game itself is great, really relaxin...
# 2       0         Roachant  My wife and I were looking forward to playing ...
# 3       0           Houndf  We need equal values and opportunities for all...
# 4       0     ProfessorFox  BEWARE!  If you have multiple people in your h...
# 5       0            tb726  The limitation of one island per Switch (not p...
# 6       0       Outryder86  I was very excited for this new installment of...
# 7       0          Subby89  It's 2020 and for some reason Nintendo has dec...
# 8       0        RocketRon  This is so annoying. Only one player has the a...
# 9       0        chankills  I purchased this game for my household (me and...
# 10      1       rafilks182  they heavily marketed this game as a social ex...
# ...

# %%
df2=df.copy()
df2
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text        date  len_text
# 0     My gf started playing before me. No option to ...  2020-03-20       381
# 1     While the game itself is great, really relaxin...  2020-03-20       927
# 2     My wife and I were looking forward to playing ...  2020-03-20      1000
# 3     We need equal values and opportunities for all...  2020-03-20       277
# 4     BEWARE!  If you have multiple people in your h...  2020-03-20       979
# ...                                                 ...         ...       ...
# ...

# %%
#using while loop

df2['super_category']=''
row=len(df2)
x = 0
while x < row:
    text=df2.loc[x,'len_text']=len(df2.loc[x,'text'])
    
    if text>1000:
        if df2.loc[x,'grade']>=9:
            df2.loc[x,'super_category']='Expert reviewer'
        elif df2.loc[x,'grade']<=1:
            df2.loc[x,'super_category']='Opposed reviewer'
        else:
            df2.loc[x,'super_category']='Super reviewer'
    else:
        df2.loc[x,'super_category']='Neutral reviewer'
    x=x+1
df2.head(50)
# Out:
#     grade        user_name                                               text  \
# 0       4         mds27272  My gf started playing before me. No option to ...
# 1       5         lolo2178  While the game itself is great, really relaxin...
# 2       0         Roachant  My wife and I were looking forward to playing ...
# 3       0           Houndf  We need equal values and opportunities for all...
# 4       0     ProfessorFox  BEWARE!  If you have multiple people in your h...
# 5       0            tb726  The limitation of one island per Switch (not p...
# 6       0       Outryder86  I was very excited for this new installment of...
# 7       0          Subby89  It's 2020 and for some reason Nintendo has dec...
# 8       0        RocketRon  This is so annoying. Only one player has the a...
# 9       0        chankills  I purchased this game for my household (me and...
# 10      1       rafilks182  they heavily marketed this game as a social ex...
# ...

# %%
df3=df.copy()
df3
# Out:
#       grade        user_name  \
# 0         4         mds27272
# 1         5         lolo2178
# 2         0         Roachant
# 3         0           Houndf
# 4         0     ProfessorFox
# ...     ...              ...
# 2994      1    TakezoShinmen
# 2995      1          Pikey17
# 2996      0        Lemmeadem
# 2997      2  TandemTester938
# 2998      4            DwerG
#
#                                                    text        date  len_text
# 0     My gf started playing before me. No option to ...  2020-03-20       381
# 1     While the game itself is great, really relaxin...  2020-03-20       927
# 2     My wife and I were looking forward to playing ...  2020-03-20      1000
# 3     We need equal values and opportunities for all...  2020-03-20       277
# 4     BEWARE!  If you have multiple people in your h...  2020-03-20       979
# ...                                                 ...         ...       ...
# ...

# %%
df3['super_category']=''

# %%
zQ
# Out:
#     grade        user_name                                               text  \
# 0       4         mds27272  My gf started playing before me. No option to ...
# 1       5         lolo2178  While the game itself is great, really relaxin...
# 2       0         Roachant  My wife and I were looking forward to playing ...
# 3       0           Houndf  We need equal values and opportunities for all...
# 4       0     ProfessorFox  BEWARE!  If you have multiple people in your h...
# 5       0            tb726  The limitation of one island per Switch (not p...
# 6       0       Outryder86  I was very excited for this new installment of...
# 7       0          Subby89  It's 2020 and for some reason Nintendo has dec...
# 8       0        RocketRon  This is so annoying. Only one player has the a...
# 9       0        chankills  I purchased this game for my household (me and...
# 10      1       rafilks182  they heavily marketed this game as a social ex...
# ...
